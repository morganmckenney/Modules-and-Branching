# %%
import pandas as pd
from step_1 import *
from step_2 import *

# %%
emp, sys_access = load_data()
emp.head()
# Out:
#   employee_number first_name last_name                             email  \
# 0       EMP003037    Juliana  Burbudge  juliana.burbudge@consultants.com
# 1       EMP003045     Lizzie      Blue       lizzie.blue@consultants.com
# 2       EMP003051    Marjory  Selcraig  marjory.selcraig@consultants.com
# 3       EMP003068     Aguste  O'Connor   aguste.o'connor@consultants.com
# 4       EMP003097    Clemens    Kopman    clemens.kopman@consultants.com
#
#                title
# 0  Director of Sales
# 1    Sales Assistant
# 2    Sales Assistant
# 3    Sales Assistant
# 4    Account Manager

# %%
sys_access.head()
# Out:
#      id    access_level
# 0  3045  Contract Entry
# 1  3051  Contract Entry
# 2  3068  Contract Entry
# 3  3097   Account Admin
# 4  3133  Contract Entry

# %%
sys_access = correct_id(sys_access)
sys_access.head()
# Out:
#   employee_number    access_level
# 0       EMP003045  Contract Entry
# 1       EMP003051  Contract Entry
# 2       EMP003068  Contract Entry
# 3       EMP003097   Account Admin
# 4       EMP003133  Contract Entry

# %%
df = join_data(emp, sys_access)
df.head()
# Out:
#                 first_name last_name                             email  \
# employee_number
# EMP003037          Juliana  Burbudge  juliana.burbudge@consultants.com
# EMP003045           Lizzie      Blue       lizzie.blue@consultants.com
# EMP003051          Marjory  Selcraig  marjory.selcraig@consultants.com
# EMP003068           Aguste  O'Connor   aguste.o'connor@consultants.com
# EMP003097          Clemens    Kopman    clemens.kopman@consultants.com
#
#                              title    access_level
# employee_number
# EMP003037        Director of Sales             NaN
# EMP003045          Sales Assistant  Contract Entry
# EMP003051          Sales Assistant  Contract Entry
# EMP003068          Sales Assistant  Contract Entry
# EMP003097          Account Manager   Account Admin

# %%
df.head(10)
# Out:
#                 first_name last_name                             email  \
# employee_number
# EMP003037          Juliana  Burbudge  juliana.burbudge@consultants.com
# EMP003045           Lizzie      Blue       lizzie.blue@consultants.com
# EMP003051          Marjory  Selcraig  marjory.selcraig@consultants.com
# EMP003068           Aguste  O'Connor   aguste.o'connor@consultants.com
# EMP003097          Clemens    Kopman    clemens.kopman@consultants.com
# EMP003133         Donielle   Midgley  donielle.midgley@consultants.com
# EMP003134          Marcela    Thieme    marcela.thieme@consultants.com
# EMP003180            Haily   Wadeson     haily.wadeson@consultants.com
# EMP003265           Natala      Judd       natala.judd@consultants.com
# EMP003287            Gayla     Aldin       gayla.aldin@consultants.com
#
#                              title    access_level
# employee_number
# EMP003037        Director of Sales             NaN
# EMP003045          Sales Assistant  Contract Entry
# EMP003051          Sales Assistant  Contract Entry
# EMP003068          Sales Assistant  Contract Entry
# EMP003097          Account Manager   Account Admin
# EMP003133          Sales Assistant  Contract Entry
# EMP003134          Sales Assistant  Contract Entry
# EMP003180          Sales Assistant  Contract Entry
# EMP003265        Director of Sales             NaN
# EMP003287          Sales Assistant  Contract Entry

# %%
subset = find_missing(df)
subset.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-aa8a988c1d6a> in <module>
# ----> 1 subset = find_missing(df)
#       2 subset.head()
#
# NameError: name 'find_missing' is not defined

# %%
new_df = map_update(subset, 'Sales Assistant', 'Contract Entry')
new_df = map_update(subset, 'Account Manager', 'Account Admin')
new_df = map_update(subset, 'Director of Sales', 'Approval - Manager')
new_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-3aead3677ff6> in <module>
# ----> 1 new_df = map_update(subset, 'Sales Assistant', 'Contract Entry')
#       2 new_df = map_update(subset, 'Account Manager', 'Account Admin')
#       3 new_df = map_update(subset, 'Director of Sales', 'Approval - Manager')
#       4 new_df.head()
#
# NameError: name 'map_update' is not defined

# %%
output_results(new_df)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-13d2da026656> in <module>
# ----> 1 output_results(new_df)
#
# NameError: name 'output_results' is not defined
